# %%
import pandas as pd
import numpy as np
import time
from concurrent.futures import ThreadPoolExecutor, as_completed
from multiprocessing import cpu_count

# %%
ruta = "BasedeDatosMoviesEDA.csv"

for enc in ["utf-8-sig", "cp1252", "latin-1", "ISO-8859-1"]:
    try:
        df = pd.read_csv(
            ruta,
            engine="python",  
            sep=None,         
            on_bad_lines="skip",
            encoding=enc
        )
        print("Cargó con encoding:", enc)
        break
    except UnicodeDecodeError as e:
        print("Falló con", enc, "->", e)

# Mostrar información del DataFrame
print(df.shape)
display(df.head())
print(df.info())
# Out:
# Cargó con encoding: utf-8-sig
# (1327800, 24)
#        id            title  vote_average  vote_count    status release_date  \
# 0   27205        Inception         8.364       34495  Released   2010-07-15
# 1  157336     Interstellar         8.417       32571  Released   2014-11-05
# 2     155  The Dark Knight         8.512       30619  Released   2008-07-16
# 3   19995           Avatar         7.573       29815  Released   2009-12-15
# 4   24428     The Avengers         7.710       29166  Released   2012-04-25
#
#       revenue  runtime  adult                     backdrop_path  ...  \
# 0   825532764      148  False  /8ZTVqvKDQ8emSGUEMjsS4yHAwrp.jpg  ...
# 1   701729206      169  False  /pbrkL804c8yAv3zBZR4QPEafpAR.jpg  ...
# 2  1004558444      152  False  /nMKdUUepR0i5zn0y1T4CsSB5chy.jpg  ...
# 3  2923706026      162  False  /vL5LR6WdxWPjLPFRLe133jXWsh5.jpg  ...
# 4  1518815515      143  False  /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg  ...
#
# ...

# %%
import numpy as np

# Se simula una variación del 5% a 15%
df["variacion"] = (df["budget"] * (1 + np.random.uniform(0.05, 0.15, len(df)))).round(2)

# Se simula un impuesto o descuento
df["impuesto"] = np.random.choice([0.05, 0.10, 0.15], size=len(df)).round(2)

# Se calcula un valor final 
df["valor_final"] = (df["variacion"] * (1 - df["impuesto"])).round(2)

# Ordenar por valor_final de mayor a menor
df = df.sort_values(by="valor_final", ascending=False)

# Imprimir el DataFrame resultante
print(df[["title", "budget", "variacion", "impuesto", "valor_final"]].head(10))
# Out:
#                                                  title     budget  \
# 812970                                  In Whose Name?  999999999
# 529421   ryan gosling der sutter logan pauls tissemand  900000000
# 515629                         Adventures in Bora Bora  800000000
# 630100                             Shadow the Hedgehog  800000000
# 593292                      ETERNIA: TWILIGHT OF STARS  873000000
# 1160400                                           Enea  888000000
# 657383                       M4's The Hobbit Book Edit  700000000
# 1192268                                         Крик 4  645654654
# 463801         Playmobil The Movie 2: Maximus' Revenge  600000000
# 830560                   Red Dead Redemption 2 (Movie)  540000000
#
#             variacion  impuesto   valor_final
# 812970   1.068668e+09      0.05  1.015235e+09
# 529421   1.025785e+09      0.05  9.744961e+08
# 515629   9.164262e+08      0.10  8.247836e+08
# 630100   9.029320e+08      0.10  8.126388e+08
# ...

# %%
df["release_date"] = pd.to_datetime(df["release_date"], format="%d/%m/%Y", errors="coerce")
records = df.to_dict(orient="records")

# %%
def quicksort(arr, key):
    if len(arr) <= 1:
        return arr
    pivot = arr[len(arr) // 2]
    left = [x for x in arr if x[key] > pivot[key]]
    mid = [x for x in arr if x[key] == pivot[key]]
    right = [x for x in arr if x[key] < pivot[key]]
    return quicksort(left, key) + mid + quicksort(right, key)

# %%
def merge_sort(arr, key):
    # Separar válidas de NaT
    valid = [x for x in arr if pd.notna(x[key])]
    invalid = [x for x in arr if pd.isna(x[key])]

    # Ordenar válidas ASCENDENTE con merge sort
    sorted_valid = merge_sort_core(valid, key)

    # Convertir a DESCENDENTE
    sorted_valid.reverse()

    # Las fechas vacías van al final
    return sorted_valid + invalid


def merge_sort_core(arr, key):
    if len(arr) <= 1:
        return arr
    mid = len(arr) // 2
    left = merge_sort_core(arr[:mid], key)
    right = merge_sort_core(arr[mid:], key)
    return merge(left, right, key)


def merge(left, right, key):
    result = []
    i = j = 0

    # ORDEN NATURAL (ASC), NO DESC
    while i < len(left) and j < len(right):
        if left[i][key] <= right[j][key]:
            result.append(left[i])
            i += 1
        else:
            result.append(right[j])
            j += 1

    result.extend(left[i:])
    result.extend(right[j:])
    return result

# %%
def ejecutar_sin_mp(data, algoritmo, key):
    copia = list(data)
    inicio = time.perf_counter()
    resultado = algoritmo(copia, key)
    fin = time.perf_counter()
    return resultado, (fin - inicio)


def worker(chunk, algoritmo, key):
    return algoritmo(chunk, key)


def ejecutar_con_mp(data, algoritmo, key):
    copia = list(data)
    num_chunks = min(cpu_count(), 4)
    chunks = np.array_split(copia, num_chunks)

    inicio = time.perf_counter()

    resultados = []
    with ThreadPoolExecutor(max_workers=num_chunks) as exe:
        futures = [exe.submit(worker, list(chunk), algoritmo, key) for chunk in chunks]
        for f in as_completed(futures):
            resultados.extend(f.result())

    # Orden final global
    resultados = algoritmo(resultados, key)

    fin = time.perf_counter()
    return resultados, (fin - inicio)

# %%
# ----- 1. Quicksort sin multiproceso (valor_final)
qs_sin, t_qs_sin = ejecutar_sin_mp(records, quicksort, "valor_final")
print("\nTiempo Quicksort sin MP:", t_qs_sin)
print(pd.DataFrame(qs_sin)[["title", "valor_final", "release_date"]].head(15))

# ----- 2. Mergesort sin multiproceso (fecha)
ms_sin, t_ms_sin = ejecutar_sin_mp(records, merge_sort, "release_date")
print("\nTiempo MergeSort sin MP:", t_ms_sin)
print(pd.DataFrame(ms_sin)[["title", "valor_final", "release_date"]].head(15))
# Out:
# Tiempo Quicksort sin MP: 1.9133197000010114
#                                             title   valor_final release_date
# 0                                  In Whose Name?  1.015235e+09          NaT
# 1   ryan gosling der sutter logan pauls tissemand  9.744961e+08          NaT
# 2                         Adventures in Bora Bora  8.247836e+08          NaT
# 3                             Shadow the Hedgehog  8.126388e+08          NaT
# 4                      ETERNIA: TWILIGHT OF STARS  8.090275e+08          NaT
# 5                                            Enea  7.930764e+08          NaT
# 6                       M4's The Hobbit Book Edit  6.888700e+08          NaT
# 7                                          Крик 4  6.696769e+08          NaT
# 8         Playmobil The Movie 2: Maximus' Revenge  6.127362e+08          NaT
# 9                   Red Dead Redemption 2 (Movie)  5.597448e+08          NaT
# 10                                       Avatar 5  5.521636e+08          NaT
# ...

# %%
qs_mp, t_qs_mp = ejecutar_con_mp(records, quicksort, "valor_final")
print("\nTiempo Quicksort con MP:", t_qs_mp)
print(pd.DataFrame(qs_mp)[["title", "valor_final", "release_date"]].head(15))


# ----- 4. MergeSort con MP (fecha DESC)
ms_mp, t_ms_mp = ejecutar_con_mp(records, merge_sort, "release_date")
print("\nTiempo MergeSort con MP:", t_ms_mp)
print(pd.DataFrame(ms_mp)[["title", "valor_final", "release_date"]].head(15))
# Out:
# Tiempo Quicksort con MP: 3.5588602000025276
#                                             title   valor_final release_date
# 0                                  In Whose Name?  1.015235e+09          NaT
# 1   ryan gosling der sutter logan pauls tissemand  9.744961e+08          NaT
# 2                         Adventures in Bora Bora  8.247836e+08          NaT
# 3                             Shadow the Hedgehog  8.126388e+08          NaT
# 4                      ETERNIA: TWILIGHT OF STARS  8.090275e+08          NaT
# 5                                            Enea  7.930764e+08          NaT
# 6                       M4's The Hobbit Book Edit  6.888700e+08          NaT
# 7                                          Крик 4  6.696769e+08          NaT
# 8         Playmobil The Movie 2: Maximus' Revenge  6.127362e+08          NaT
# 9                   Red Dead Redemption 2 (Movie)  5.597448e+08          NaT
# 10                                       Avatar 5  5.521636e+08          NaT
# ...

# %%
print("\n===== COMPARACIÓN DE RENDIMIENTO =====")
print(f"Quicksort sin MP: {t_qs_sin:.4f}s")
print(f"Quicksort con MP: {t_qs_mp:.4f}s | Mejora: {((t_qs_sin - t_qs_mp)/t_qs_sin*100):.2f}%")
print()
print(f"MergeSort sin MP: {t_ms_sin:.4f}s")
print(f"MergeSort con MP: {t_ms_mp:.4f}s | Mejora: {((t_ms_sin - t_ms_mp)/t_ms_sin*100):.2f}%")
# Out:
# ===== COMPARACIÓN DE RENDIMIENTO =====
# Quicksort sin MP: 1.9133s
# Quicksort con MP: 3.5589s | Mejora: -86.00%
#
# MergeSort sin MP: 2.7714s
# MergeSort con MP: 3.8775s | Mejora: -39.91%
